# %%
import pandas as pd

# %%
df = pd.read_excel(r"C:\Users\limc_\Downloads\PRUEBA REMA (1).xlsx")
df
# Out:
#    INDICADOR;GEO;CATEGORÍA AMBIENTAL;ODS;NACIONAL;I REGIÓN;II REGIÓN;III REGIÓN;IV REGIÓN;ENLACE  \
# 0   Evolución de las anomalías de las temperaturas...
# 1   Evolución de las anomalias de las temperaturas...
# 2     Evolución de las precipitaciones promedio anual
# 3   Evolución de la superficie plantada de cepajes...
# 4   Superficie de plantaciones forestales por regi...
# 5   Evolución de la superficie de plantaciones for...
# 6   Expansión urbana en Chile y ciudades seleccion...
# 7   Número total de especies animales descritas y ...
# 8   Número total de especies de plantas y árboles ...
# 9   Desembarque pesquero total por región y catego...
# 10  Desembarque pesquero total por régimen y categ...
# 11  Evolución del desembarque pesquero total por c...
# 12  Evolución del estado de situación de las pesqu...
# 13  Fondo para el Reciclaje - Nº de proyectos y mo...
# 14  Evolución de la tasa nacional de valorización;...
# 15  Total de recicladores de base certificados seg...
# ...

# %%
df.to_json("ejemplo.json")
